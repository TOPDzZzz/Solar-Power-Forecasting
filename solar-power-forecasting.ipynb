# %%
# !pip install -r /home/mw/project/requirements.txt
# !pip install Optuna
# !pip install --upgrade xgboost

# %%
# !python /src/baseline_model.py

# %%
# !python /src/predict.py
# Out:
# ======== Predict.csv 评估结果（t+1） ========
# 样本数: 10076
# 特征数: 39
# RMSE : 789.7560
# MSE  : 623714.6007
# MAE  : 294.1781
# R2   : 0.9086
# ...
